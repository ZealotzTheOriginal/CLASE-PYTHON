# %% [markdown]
# Libreria Math

# %%
cuadrados = [x**2 for x in range(10)]
print(cuadrados)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
edades = [23,42,21,12,23,34]
new_list = []

for edad in edades:
    if edad % 2 == 0:
        new_list.append(edad/2)

new_list
# Out:
# [21.0, 6.0, 17.0]

# %%
edades = [23,42,21,12,23,34]
nueva_lista = [edad/2 for edad in edades]
nueva_lista
# Out:
# [11.5, 21.0, 10.5, 6.0, 11.5, 17.0]

# %%
edades = [23,42,21,12,23,34]
nueva_lista = [edad/2 for edad in edades]
nueva_lista
# Out:
# [11.5, 21.0, 10.5, 6.0, 11.5, 17.0]

# %%
import math

raiz_cuadrada_math = math.sqrt(4782)
raiz_cuadrada_math

import datetime
# Out:
# <module 'datetime' from 'c:\\Python313\\Lib\\datetime.py'>
