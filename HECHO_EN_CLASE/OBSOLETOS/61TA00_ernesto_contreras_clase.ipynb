# %% [markdown]
# Ejercicio 1

# %% [markdown]
# Ejercicio 2

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# Ejercicio 4

# %% [markdown]
# Ejercicio 5

# %% [markdown]
# Ejercicio 6

# %% [markdown]
# Ejercicio 7

# %% [markdown]
# Ejercicio 8

# %% [markdown]
# Ejercicio 9
